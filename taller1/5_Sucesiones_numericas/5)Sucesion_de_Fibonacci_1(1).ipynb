# %%
#creado por Nicolas Daza & Sebastian Hurtado
import matplotlib.pyplot as ptl
def fibonacci(cantidad_numeros:int):
    a=0
    b=1
    suma=0
    n=0
    sucesion=[0,1]
   
    while n < (cantidad_numeros-1):
        suma=a+b
        sucesion.append(suma)
        a=b
        b=suma
        n +=1
   
    '''grafica
    N=cantidad_numeros+1
    matriz=np.zeros((N,2))
    for x in range(0,len(sucesion)):
        matriz[x,0]=sucesion[x]
   
    eje_x=[]
    for x in range(0,N):
        eje_x.append(x)
   
    for x in range(len(eje_x)):
        matriz[x,1]=eje_x[x]'''
       
    ptl.plot(sucesion)
    ptl.show()
   
   
    return sucesion


def Numero_aureo(n_numeros:int):
   
    sucesion=fibonacci(n_numeros)
    lista_infinito=[]
    for x in range(2,len(sucesion)):
        proporcion=(sucesion[x])/(sucesion[x-1])
        lista_infinito.append(proporcion)
    au=[]
    for x in range(2,len(sucesion)):
        aur=1.618033
        au.append(aur)
    ptl.plot(lista_infinito,label="estimacion usando la serie", color='r')
    ptl.plot(au,label='numero aureo',color='b')
    ptl.show()
    return lista_infinito

print(Numero_aureo(40), "este lista representa la proporcion del numero aureo segun "+
      "la sucesion de fibonacci al infinito, segun la relacion  fn/f(n-1), la cual concuerda "
      "con el numero real")
# Out:
# [1.0, 2.0, 1.5, 1.6666666666666667, 1.6, 1.625, 1.6153846153846154, 1.619047619047619, 1.6176470588235294, 1.6181818181818182, 1.6179775280898876, 1.6180555555555556, 1.6180257510729614, 1.6180371352785146, 1.618032786885246, 1.618034447821682, 1.6180338134001253, 1.618034055727554, 1.6180339631667064, 1.6180339985218033, 1.618033985017358, 1.6180339901755971, 1.618033988205325, 1.618033988957902, 1.6180339886704431, 1.6180339887802426, 1.618033988738303, 1.6180339887543225, 1.6180339887482036, 1.6180339887505408, 1.6180339887496482, 1.618033988749989, 1.618033988749859, 1.6180339887499087, 1.6180339887498896, 1.618033988749897, 1.618033988749894, 1.6180339887498951, 1.6180339887498947] este lista representa la proporcion del numero aureo segun la sucesion de fibonacci al infinito, segun la relacion  fn/f(n-1), la cual concuerda con el numero real
